# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import re 
import pyautogui
import warnings
warnings.filterwarnings("ignore")

# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비
columns = ["title", "url", "content_text"]
df = pd.DataFrame(columns=columns)

excutable_path = "chromedriver.exe"

base_url = 'https://ko.wikipedia.org/'

def urlmake(links):
    source = base_url + links
    driver.get(source)
    req = driver.page_source
    soup = BeautifulSoup(req, "html.parser") 
    return soup

driver = webdriver.Chrome(executable_path=excutable_path)

base_link = "/wiki/%ED%8A%B9%EC%88%98:%EC%B5%9C%EA%B7%BC%EB%B0%94%EB%80%9C?hidebots=1&hidecategorization=1&hideWikibase=1&limit=50&days=7&urlversion=2"

title_list = urlmake(base_link).select('.mw-title')

keyword = pyautogui.prompt(f"원하는 갯수를 입력하세요.최대 갯수: {len(title_list)}")
num = 0

for i in range(int(keyword)):
    title = title_list[i].select_one('.mw-changeslist-title').text
    link = title_list[i].select_one('a').attrs['href']
    contents = urlmake(link).select_one('.mw-parser-output>p')
    num += 1
    # 그냥 주피터에서 출력 시 
    print(f'-----------------------num{num}-----------------------')
    print(f'title: \t{title}\nurl: \t{base_url+link}')
    if(contents != None and contents != ''):
        print(f'contents: \n{contents.text}')
    else:
        print('contents : NOPE')
    if(num == int(keyword)):

        print(f'-----------------------end-----------------------')

    # 데이터 프레임으로 만들고 싶을시
    if contents == None:
        contents = ''
    else:
        contents = contents.text
    row = [title,base_url+link,re.sub('\n',' , ',contents)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)
df
# Out:
# -----------------------num1-----------------------
# title: 	무인시대 (드라마)
# url: 	https://ko.wikipedia.org//wiki/%EB%AC%B4%EC%9D%B8%EC%8B%9C%EB%8C%80_(%EB%93%9C%EB%9D%BC%EB%A7%88)
# contents:
# 《무인시대》(武人時代)는 2003년 2월 8일부터 2004년 8월 15일까지 방송된 KBS 1TV 대하드라마다.
#
# -----------------------num2-----------------------
# title: 	M.SS.41
# url: 	https://ko.wikipedia.org//wiki/M.SS.41
# contents:
# M.SS.41 또는 41식 무장친위대용 대전차소총은 나치 독일및 체코슬로바키아에서 1941년 생산한 대전차 소총이다.
#
# -----------------------num3-----------------------
# title: 	코파 수다메리카나 2021
# url: 	https://ko.wikipedia.org//w/index.php?title=%EC%BD%94%ED%8C%8C_%EC%88%98%EB%8B%A4%EB%A9%94%EB%A6%AC%EC%B9%B4%EB%82%98_2021&redirect=no
# contents : NOPE
# -----------------------num4-----------------------
# title: 	2021 코파 수다메리카나
# url: 	https://ko.wikipedia.org//w/index.php?title=2021_%EC%BD%94%ED%8C%8C_%EC%88%98%EB%8B%A4%EB%A9%94%EB%A6%AC%EC%B9%B4%EB%82%98&redirect=no
# contents : NOPE
# -----------------------num5-----------------------
# title: 	검역
# url: 	https://ko.wikipedia.org//wiki/%EA%B2%80%EC%97%AD
# contents:
# 검역(檢疫, 영어: quarantine)은 국외 감염병이 국내로 유입되는 것을 예방하기 위해 공항, 항구 등에서 검사하는 것을 말한다.
#
# -----------------------end-----------------------
#             title                                                url  \
# 0      무인시대 (드라마)  https://ko.wikipedia.org//wiki/%EB%AC%B4%EC%9D...
# 1         M.SS.41             https://ko.wikipedia.org//wiki/M.SS.41
# 2  코파 수다메리카나 2021  https://ko.wikipedia.org//w/index.php?title=%E...
# 3  2021 코파 수다메리카나  https://ko.wikipedia.org//w/index.php?title=20...
# 4              검역  https://ko.wikipedia.org//wiki/%EA%B2%80%EC%97%AD
#
#                                         content_text
# 0  《무인시대》(武人時代)는 2003년 2월 8일부터 2004년 8월 15일까지 방송된...
# 1  M.SS.41 또는 41식 무장친위대용 대전차소총은 나치 독일및 체코슬로바키아에서 ...
# 2
# 3
# 4  검역(檢疫, 영어: quarantine)은 국외 감염병이 국내로 유입되는 것을 예방...
