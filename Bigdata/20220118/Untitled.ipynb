# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import re 
import pyautogui
import warnings
warnings.filterwarnings("ignore")

# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비
columns = ["title", "url", "content_text"]
df = pd.DataFrame(columns=columns)

excutable_path = "chromedriver.exe"

base_url = 'https://ko.wikipedia.org/'

def urlmake(links):
    source = base_url + links
    driver.get(source)
    req = driver.page_source
    soup = BeautifulSoup(req, "html.parser") 
    return soup

driver = webdriver.Chrome(executable_path=excutable_path)

base_link = "/wiki/%ED%8A%B9%EC%88%98:%EC%B5%9C%EA%B7%BC%EB%B0%94%EB%80%9C?hidebots=1&hidecategorization=1&hideWikibase=1&limit=50&days=7&urlversion=2"

title_list = urlmake(base_link).select('.mw-title')

keyword = pyautogui.prompt(f"원하는 갯수를 입력하세요.최대 갯수: {len(title_list)}")
num = 0

for i in range(int(keyword)):
    title = title_list[i].select_one('.mw-changeslist-title').text
    link = title_list[i].select_one('a').attrs['href']
    contents = urlmake(link).select_one('.mw-parser-output>p')
    num += 1
    # 그냥 주피터에서 출력 시 
    print(f'-----------------------num{num}-----------------------')
    print(f'title: \t{title}\nurl: \t{base_url+link}')
    if(contents != None and contents != ''):
        print(f'contents: \n{contents.text}')
    else:
        print('contents : NOPE')
    if(num == int(keyword)):

        print(f'-----------------------end-----------------------')

    # 데이터 프레임으로 만들고 싶을시
    if contents == None:
        contents = ''
    else:
        contents = contents.text
    row = [title,base_url+link,re.sub('\n',' , ',contents)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)
df
# Out:
# -----------------------num1-----------------------
# title: 	게토레이
# url: 	https://ko.wikipedia.org//wiki/%EA%B2%8C%ED%86%A0%EB%A0%88%EC%9D%B4
# contents:
# 게토레이(영어: Gatorade 게이터레이드[*])는 펩시코의 부서인 퀘이커 오츠를 통해, Stokely-Van Camp사가 시장에 내 놓은 탄산이 없는 스포츠 드링크이다. 원래 운동 선수들을 위해 고안되었으나, 지금은 간편히 사 먹을 수 있는 음료로 자리잡았다.
# 이 음료는 특히 따뜻한 날씨에 에어로빅 운동을 하는 동안 탄수화물, 전해질(나트륨, 칼륨 염분)을 재수화하고 보충하기 위해 만들어졌다.[3]
#
# -----------------------num2-----------------------
# title: 	라우터브루넨
# url: 	https://ko.wikipedia.org//wiki/%EB%9D%BC%EC%9A%B0%ED%84%B0%EB%B8%8C%EB%A3%A8%EB%84%A8
# contents:
# 라우터브루넨(독일어: Lauterbrunnen)는 스위스 베른주에 위치한 도시로, 면적은 164.56km2, 높이는 795m, 인구는 2,558명(2010년 기준), 인구 밀도는 16명/km2이다. 빙하의 침식으로 인해 형성된 빙하곡과 접해 있으며 70여 개가 넘는 골짜기와 폭포로 유명한 도시이다. 많은 관광객들이 슈타우바흐 폭포와 눈덮인 알프스 산악지대의 풍경을 보기위해 모여들어, 많은 호텔들이 들어서있다.
# 라우터브루넨 역을 통해 융프라우로 갈 수 있다.
#
# -----------------------num3-----------------------
# title: 	게토레이
# url: 	https://ko.wikipedia.org//wiki/%EA%B2%8C%ED%86%A0%EB%A0%88%EC%9D%B4
# contents:
# 게토레이(영어: Gatorade 게이터레이드[*])는 펩시코의 부서인 퀘이커 오츠를 통해, Stokely-Van Camp사가 시장에 내 놓은 탄산이 없는 스포츠 드링크이다. 원래 운동 선수들을 위해 고안되었으나, 지금은 간편히 사 먹을 수 있는 음료로 자리잡았다.
# 이 음료는 특히 따뜻한 날씨에 에어로빅 운동을 하는 동안 탄수화물, 전해질(나트륨, 칼륨 염분)을 재수화하고 보충하기 위해 만들어졌다.[3]
#
# -----------------------num4-----------------------
# title: 	최용득
# url: 	https://ko.wikipedia.org//wiki/%EC%B5%9C%EC%9A%A9%EB%93%9D
# contents:
# 최용득(崔容得, 1947년 4월 20일 ~ )은 대한민국의 정치인이다. 제41,45대 전라북도 장수군수이다.
#
# -----------------------num5-----------------------
# title: 	김상두
# url: 	https://ko.wikipedia.org//wiki/%EA%B9%80%EC%83%81%EB%91%90
# contents:
# 김상두(1934년 2월 12일 ~ 2015년 11월 11일)는 대한민국의 정치인이다. 제39·40대 장수군수를 역임했다.
#
# -----------------------num6-----------------------
# title: 	한국방송 성우극회
# url: 	https://ko.wikipedia.org//wiki/%ED%95%9C%EA%B5%AD%EB%B0%A9%EC%86%A1_%EC%84%B1%EC%9A%B0%EA%B7%B9%ED%9A%8C
# contents:
# 한국방송 성우극회(韓國放送 聲優劇會)는 한국방송공사에서 운영하는 대한민국 방송의 성우 단체이다.
#
# -----------------------num7-----------------------
# title: 	위키백과:사랑방/2022년 제3주
# url: 	https://ko.wikipedia.org//wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EC%82%AC%EB%9E%91%EB%B0%A9/2022%EB%85%84_%EC%A0%9C3%EC%A3%BC
# contents:
# --YKo (WMF) (토론) 2022년 1월 18일 (화) 15:58 (KST)[답변]
#
# -----------------------num8-----------------------
# title: 	천궈쿤
# url: 	https://ko.wikipedia.org//wiki/%EC%B2%9C%EA%B6%88%EC%BF%A4
# contents:
# 천궈쿤(陳國坤, 1975년 8월 1일 ~ )은 홍콩의 배우이다. 원래 안무가였는데 이소룡을 쏙빼닮은 얼굴 때문에 저우싱츠에게 발탁되어 소림축구에 출연한 것을 계기로 배우로 데뷔했다. 이후 천궈쿤은 이소룡 전문배우가 되었다.
#
# -----------------------num9-----------------------
# title: 	라우터브루넨
# url: 	https://ko.wikipedia.org//wiki/%EB%9D%BC%EC%9A%B0%ED%84%B0%EB%B8%8C%EB%A3%A8%EB%84%A8
